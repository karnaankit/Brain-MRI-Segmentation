# %%
import os
import cv2
import glob
import PIL
import random
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage 
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps  


# neural imaging
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt
# !pip install git+https://github.com/miykael/gif_your_nifti # nifti to gif 
# import gif_your_nifti.core as gif2nif


# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/nilearn/__init__.py:69: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3 later
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
VOLUME_SLICES = 145
VOLUME_START_AT = 5
 # first slice of volume that we will include

# %%
TRAIN_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
VALIDATION_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData'

test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii').get_fdata()
test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1.nii').get_fdata()
test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1ce.nii').get_fdata()
test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t2.nii').get_fdata()
test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii').get_fdata()


fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w = 25
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_t1ce[:,:,test_image_t1ce.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image t1ce')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_mask[:,:,test_mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1e-6):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)
 
def comb_loss(y_true, y_pred):
    return 0.5*tf.keras.losses.categorical_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
# define per class evaluation of dice coef
# inspired by https://github.com/keras-team/keras/issues/9395
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)
def dice_normal(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,0] * y_pred[:,:,:,0]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,0])) + K.sum(K.square(y_pred[:,:,:,0])) + epsilon)



# Computing Precision 
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    
# Computing Sensitivity      
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
IMG_SIZE = 128

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics = [tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity,dice_loss, dice_normal, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing] )

# %%
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# file BraTS20_Training_355 has ill formatted name for for seg.nii file
train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))

        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            ce = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()
            
            for j in range(VOLUME_SLICES):
                  X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                  X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                  y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
                    
        # Generate masks
        y[y==4] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()
    
showDataLayout()

# %%
csv_logger = CSVLogger('training.log', separator=',', append=False)


callbacks = [
      keras.callbacks.EarlyStopping(monitor='val_comb_loss', min_delta=0,
                               patience=6, verbose=1, mode='auto'),
      keras.callbacks.ReduceLROnPlateau(monitor='val_comb_loss', factor=0.1,
                              patience=2, min_lr=0.000001, verbose=1),
      keras.callbacks.ModelCheckpoint(filepath = 'model_weights.h5',
                             verbose=1,monitor='val_comb_loss', save_best_only=True, save_weights_only = True),
      csv_logger
    ]

# %%
model.load_weights('/kaggle/working/model_weights.h5')

# %%
K.clear_session()

history =  model.fit(training_generator,
                    epochs=1000,
                    steps_per_epoch=len(training_generator),
                    callbacks= callbacks,
                    validation_data = valid_generator
                    )  
model.save("model_x1_1.h5")
# Out:
# Epoch 1/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0925 - mean_io_u: 0.6586 - dice_coef: 0.2704 - precision: 0.9831 - sensitivity: 0.9736 - specificity: 0.9959 - dice_loss: 0.7296 - dice_normal: 0.9887 - dice_coef_necrotic: 0.0547 - dice_coef_edema: 0.1370 - dice_coef_enhancing: 0.0503
# Epoch 1: val_dice_loss improved from inf to 0.72326, saving model to model_weights.h5
# 249/249 [==============================] - 276s 1s/step - loss: 0.0925 - mean_io_u: 0.6586 - dice_coef: 0.2704 - precision: 0.9831 - sensitivity: 0.9736 - specificity: 0.9959 - dice_loss: 0.7296 - dice_normal: 0.9887 - dice_coef_necrotic: 0.0547 - dice_coef_edema: 0.1370 - dice_coef_enhancing: 0.0503 - val_loss: 0.0419 - val_mean_io_u: 0.6140 - val_dice_coef: 0.2767 - val_precision: 0.9899 - val_sensitivity: 0.9899 - val_specificity: 0.9966 - val_dice_loss: 0.7233 - val_dice_normal: 0.9958 - val_dice_coef_necrotic: 0.0610 - val_dice_coef_edema: 0.1629 - val_dice_coef_enhancing: 0.0491 - lr: 0.0010
# Epoch 2/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0523 - mean_io_u: 0.6827 - dice_coef: 0.2870 - precision: 0.9883 - sensitivity: 0.9863 - specificity: 0.9961 - dice_loss: 0.7130 - dice_normal: 0.9948 - dice_coef_necrotic: 0.0906 - dice_coef_edema: 0.1790 - dice_coef_enhancing: 0.0856
# Epoch 2: val_dice_loss improved from 0.72326 to 0.72029, saving model to model_weights.h5
# 249/249 [==============================] - 247s 989ms/step - loss: 0.0523 - mean_io_u: 0.6827 - dice_coef: 0.2870 - precision: 0.9883 - sensitivity: 0.9863 - specificity: 0.9961 - dice_loss: 0.7130 - dice_normal: 0.9948 - dice_coef_necrotic: 0.0906 - dice_coef_edema: 0.1790 - dice_coef_enhancing: 0.0856 - val_loss: 0.0401 - val_mean_io_u: 0.3766 - val_dice_coef: 0.2797 - val_precision: 0.9899 - val_sensitivity: 0.9899 - val_specificity: 0.9966 - val_dice_loss: 0.7203 - val_dice_normal: 0.9961 - val_dice_coef_necrotic: 0.1026 - val_dice_coef_edema: 0.1590 - val_dice_coef_enhancing: 0.0424 - lr: 0.0010
# Epoch 3/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0449 - mean_io_u: 0.6977 - dice_coef: 0.3119 - precision: 0.9904 - sensitivity: 0.9861 - specificity: 0.9968 - dice_loss: 0.6881 - dice_normal: 0.9958 - dice_coef_necrotic: 0.1466 - dice_coef_edema: 0.2289 - dice_coef_enhancing: 0.1678
# Epoch 3: val_dice_loss improved from 0.72029 to 0.66806, saving model to model_weights.h5
# 249/249 [==============================] - 236s 945ms/step - loss: 0.0449 - mean_io_u: 0.6977 - dice_coef: 0.3119 - precision: 0.9904 - sensitivity: 0.9861 - specificity: 0.9968 - dice_loss: 0.6881 - dice_normal: 0.9958 - dice_coef_necrotic: 0.1466 - dice_coef_edema: 0.2289 - dice_coef_enhancing: 0.1678 - val_loss: 0.0323 - val_mean_io_u: 0.7425 - val_dice_coef: 0.3319 - val_precision: 0.9943 - val_sensitivity: 0.9869 - val_specificity: 0.9980 - val_dice_loss: 0.6681 - val_dice_normal: 0.9968 - val_dice_coef_necrotic: 0.1849 - val_dice_coef_edema: 0.2671 - val_dice_coef_enhancing: 0.2153 - lr: 0.0010
# Epoch 4/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0426 - mean_io_u: 0.7485 - dice_coef: 0.3377 - precision: 0.9917 - sensitivity: 0.9857 - specificity: 0.9972 - dice_loss: 0.6623 - dice_normal: 0.9961 - dice_coef_necrotic: 0.1870 - dice_coef_edema: 0.2792 - dice_coef_enhancing: 0.2415
# Epoch 4: val_dice_loss did not improve from 0.66806
# 249/249 [==============================] - 223s 895ms/step - loss: 0.0426 - mean_io_u: 0.7485 - dice_coef: 0.3377 - precision: 0.9917 - sensitivity: 0.9857 - specificity: 0.9972 - dice_loss: 0.6623 - dice_normal: 0.9961 - dice_coef_necrotic: 0.1870 - dice_coef_edema: 0.2792 - dice_coef_enhancing: 0.2415 - val_loss: 0.0342 - val_mean_io_u: 0.6316 - val_dice_coef: 0.3061 - val_precision: 0.9904 - val_sensitivity: 0.9899 - val_specificity: 0.9968 - val_dice_loss: 0.6939 - val_dice_normal: 0.9968 - val_dice_coef_necrotic: 0.1422 - val_dice_coef_edema: 0.2262 - val_dice_coef_enhancing: 0.1873 - lr: 0.0010
# Epoch 5/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0364 - mean_io_u: 0.7147 - dice_coef: 0.3625 - precision: 0.9928 - sensitivity: 0.9859 - specificity: 0.9975 - dice_loss: 0.6375 - dice_normal: 0.9967 - dice_coef_necrotic: 0.2123 - dice_coef_edema: 0.3394 - dice_coef_enhancing: 0.3130
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 5: val_dice_loss did not improve from 0.66806
# 249/249 [==============================] - 229s 917ms/step - loss: 0.0364 - mean_io_u: 0.7147 - dice_coef: 0.3625 - precision: 0.9928 - sensitivity: 0.9859 - specificity: 0.9975 - dice_loss: 0.6375 - dice_normal: 0.9967 - dice_coef_necrotic: 0.2123 - dice_coef_edema: 0.3394 - dice_coef_enhancing: 0.3130 - val_loss: 0.0307 - val_mean_io_u: 0.6734 - val_dice_coef: 0.3282 - val_precision: 0.9918 - val_sensitivity: 0.9898 - val_specificity: 0.9973 - val_dice_loss: 0.6718 - val_dice_normal: 0.9971 - val_dice_coef_necrotic: 0.1621 - val_dice_coef_edema: 0.2742 - val_dice_coef_enhancing: 0.1379 - lr: 0.0010
# Epoch 6/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0290 - mean_io_u: 0.7224 - dice_coef: 0.3926 - precision: 0.9938 - sensitivity: 0.9874 - specificity: 0.9978 - dice_loss: 0.6074 - dice_normal: 0.9976 - dice_coef_necrotic: 0.2295 - dice_coef_edema: 0.4392 - dice_coef_enhancing: 0.3866
# Epoch 6: val_dice_loss improved from 0.66806 to 0.59375, saving model to model_weights.h5
# 249/249 [==============================] - 230s 923ms/step - loss: 0.0290 - mean_io_u: 0.7224 - dice_coef: 0.3926 - precision: 0.9938 - sensitivity: 0.9874 - specificity: 0.9978 - dice_loss: 0.6074 - dice_normal: 0.9976 - dice_coef_necrotic: 0.2295 - dice_coef_edema: 0.4392 - dice_coef_enhancing: 0.3866 - val_loss: 0.0219 - val_mean_io_u: 0.7683 - val_dice_coef: 0.4062 - val_precision: 0.9957 - val_sensitivity: 0.9896 - val_specificity: 0.9985 - val_dice_loss: 0.5938 - val_dice_normal: 0.9983 - val_dice_coef_necrotic: 0.2466 - val_dice_coef_edema: 0.4972 - val_dice_coef_enhancing: 0.4306 - lr: 1.0000e-04
# Epoch 7/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0253 - mean_io_u: 0.7652 - dice_coef: 0.4262 - precision: 0.9942 - sensitivity: 0.9884 - specificity: 0.9980 - dice_loss: 0.5738 - dice_normal: 0.9981 - dice_coef_necrotic: 0.2617 - dice_coef_edema: 0.5034 - dice_coef_enhancing: 0.4621
# Epoch 7: val_dice_loss improved from 0.59375 to 0.57398, saving model to model_weights.h5
# 249/249 [==============================] - 227s 908ms/step - loss: 0.0253 - mean_io_u: 0.7652 - dice_coef: 0.4262 - precision: 0.9942 - sensitivity: 0.9884 - specificity: 0.9980 - dice_loss: 0.5738 - dice_normal: 0.9981 - dice_coef_necrotic: 0.2617 - dice_coef_edema: 0.5034 - dice_coef_enhancing: 0.4621 - val_loss: 0.0199 - val_mean_io_u: 0.7567 - val_dice_coef: 0.4260 - val_precision: 0.9955 - val_sensitivity: 0.9913 - val_specificity: 0.9984 - val_dice_loss: 0.5740 - val_dice_normal: 0.9985 - val_dice_coef_necrotic: 0.2764 - val_dice_coef_edema: 0.5370 - val_dice_coef_enhancing: 0.4349 - lr: 1.0000e-04
# Epoch 8/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0233 - mean_io_u: 0.7719 - dice_coef: 0.4485 - precision: 0.9941 - sensitivity: 0.9896 - specificity: 0.9980 - dice_loss: 0.5515 - dice_normal: 0.9983 - dice_coef_necrotic: 0.2893 - dice_coef_edema: 0.5428 - dice_coef_enhancing: 0.4961
# Epoch 8: val_dice_loss improved from 0.57398 to 0.56028, saving model to model_weights.h5
# 249/249 [==============================] - 230s 923ms/step - loss: 0.0233 - mean_io_u: 0.7719 - dice_coef: 0.4485 - precision: 0.9941 - sensitivity: 0.9896 - specificity: 0.9980 - dice_loss: 0.5515 - dice_normal: 0.9983 - dice_coef_necrotic: 0.2893 - dice_coef_edema: 0.5428 - dice_coef_enhancing: 0.4961 - val_loss: 0.0197 - val_mean_io_u: 0.7787 - val_dice_coef: 0.4397 - val_precision: 0.9957 - val_sensitivity: 0.9910 - val_specificity: 0.9985 - val_dice_loss: 0.5603 - val_dice_normal: 0.9985 - val_dice_coef_necrotic: 0.3349 - val_dice_coef_edema: 0.5670 - val_dice_coef_enhancing: 0.4533 - lr: 1.0000e-04
# Epoch 9/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0218 - mean_io_u: 0.7911 - dice_coef: 0.4689 - precision: 0.9945 - sensitivity: 0.9901 - specificity: 0.9981 - dice_loss: 0.5311 - dice_normal: 0.9984 - dice_coef_necrotic: 0.3220 - dice_coef_edema: 0.5708 - dice_coef_enhancing: 0.5332
# Epoch 9: val_dice_loss improved from 0.56028 to 0.53672, saving model to model_weights.h5
# 249/249 [==============================] - 220s 883ms/step - loss: 0.0218 - mean_io_u: 0.7911 - dice_coef: 0.4689 - precision: 0.9945 - sensitivity: 0.9901 - specificity: 0.9981 - dice_loss: 0.5311 - dice_normal: 0.9984 - dice_coef_necrotic: 0.3220 - dice_coef_edema: 0.5708 - dice_coef_enhancing: 0.5332 - val_loss: 0.0176 - val_mean_io_u: 0.7901 - val_dice_coef: 0.4633 - val_precision: 0.9956 - val_sensitivity: 0.9925 - val_specificity: 0.9985 - val_dice_loss: 0.5367 - val_dice_normal: 0.9988 - val_dice_coef_necrotic: 0.3383 - val_dice_coef_edema: 0.6055 - val_dice_coef_enhancing: 0.4819 - lr: 1.0000e-04
# Epoch 10/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0206 - mean_io_u: 0.8022 - dice_coef: 0.4852 - precision: 0.9946 - sensitivity: 0.9906 - specificity: 0.9981 - dice_loss: 0.5148 - dice_normal: 0.9986 - dice_coef_necrotic: 0.3480 - dice_coef_edema: 0.5947 - dice_coef_enhancing: 0.5493
# Epoch 10: val_dice_loss improved from 0.53672 to 0.51672, saving model to model_weights.h5
# 249/249 [==============================] - 222s 891ms/step - loss: 0.0206 - mean_io_u: 0.8022 - dice_coef: 0.4852 - precision: 0.9946 - sensitivity: 0.9906 - specificity: 0.9981 - dice_loss: 0.5148 - dice_normal: 0.9986 - dice_coef_necrotic: 0.3480 - dice_coef_edema: 0.5947 - dice_coef_enhancing: 0.5493 - val_loss: 0.0168 - val_mean_io_u: 0.8127 - val_dice_coef: 0.4833 - val_precision: 0.9959 - val_sensitivity: 0.9925 - val_specificity: 0.9986 - val_dice_loss: 0.5167 - val_dice_normal: 0.9988 - val_dice_coef_necrotic: 0.3570 - val_dice_coef_edema: 0.5951 - val_dice_coef_enhancing: 0.5507 - lr: 1.0000e-04
# Epoch 11/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0196 - mean_io_u: 0.8065 - dice_coef: 0.5007 - precision: 0.9946 - sensitivity: 0.9911 - specificity: 0.9981 - dice_loss: 0.4993 - dice_normal: 0.9987 - dice_coef_necrotic: 0.3652 - dice_coef_edema: 0.6165 - dice_coef_enhancing: 0.5798
# Epoch 11: val_dice_loss did not improve from 0.51672
# 249/249 [==============================] - 234s 938ms/step - loss: 0.0196 - mean_io_u: 0.8065 - dice_coef: 0.5007 - precision: 0.9946 - sensitivity: 0.9911 - specificity: 0.9981 - dice_loss: 0.4993 - dice_normal: 0.9987 - dice_coef_necrotic: 0.3652 - dice_coef_edema: 0.6165 - dice_coef_enhancing: 0.5798 - val_loss: 0.0177 - val_mean_io_u: 0.7990 - val_dice_coef: 0.4817 - val_precision: 0.9961 - val_sensitivity: 0.9916 - val_specificity: 0.9986 - val_dice_loss: 0.5183 - val_dice_normal: 0.9986 - val_dice_coef_necrotic: 0.3855 - val_dice_coef_edema: 0.6142 - val_dice_coef_enhancing: 0.5573 - lr: 1.0000e-04
# Epoch 12/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0192 - mean_io_u: 0.8089 - dice_coef: 0.5090 - precision: 0.9948 - sensitivity: 0.9912 - specificity: 0.9982 - dice_loss: 0.4910 - dice_normal: 0.9987 - dice_coef_necrotic: 0.3782 - dice_coef_edema: 0.6308 - dice_coef_enhancing: 0.5787
# Epoch 12: val_dice_loss improved from 0.51672 to 0.50430, saving model to model_weights.h5
# 249/249 [==============================] - 229s 917ms/step - loss: 0.0192 - mean_io_u: 0.8089 - dice_coef: 0.5090 - precision: 0.9948 - sensitivity: 0.9912 - specificity: 0.9982 - dice_loss: 0.4910 - dice_normal: 0.9987 - dice_coef_necrotic: 0.3782 - dice_coef_edema: 0.6308 - dice_coef_enhancing: 0.5787 - val_loss: 0.0158 - val_mean_io_u: 0.8193 - val_dice_coef: 0.4957 - val_precision: 0.9960 - val_sensitivity: 0.9931 - val_specificity: 0.9986 - val_dice_loss: 0.5043 - val_dice_normal: 0.9989 - val_dice_coef_necrotic: 0.3750 - val_dice_coef_edema: 0.6272 - val_dice_coef_enhancing: 0.5624 - lr: 1.0000e-04
# Epoch 13/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0184 - mean_io_u: 0.8107 - dice_coef: 0.5182 - precision: 0.9949 - sensitivity: 0.9916 - specificity: 0.9983 - dice_loss: 0.4818 - dice_normal: 0.9988 - dice_coef_necrotic: 0.3965 - dice_coef_edema: 0.6402 - dice_coef_enhancing: 0.5961
# Epoch 13: val_dice_loss improved from 0.50430 to 0.49229, saving model to model_weights.h5
# 249/249 [==============================] - 223s 897ms/step - loss: 0.0184 - mean_io_u: 0.8107 - dice_coef: 0.5182 - precision: 0.9949 - sensitivity: 0.9916 - specificity: 0.9983 - dice_loss: 0.4818 - dice_normal: 0.9988 - dice_coef_necrotic: 0.3965 - dice_coef_edema: 0.6402 - dice_coef_enhancing: 0.5961 - val_loss: 0.0160 - val_mean_io_u: 0.8238 - val_dice_coef: 0.5077 - val_precision: 0.9957 - val_sensitivity: 0.9933 - val_specificity: 0.9985 - val_dice_loss: 0.4923 - val_dice_normal: 0.9989 - val_dice_coef_necrotic: 0.3760 - val_dice_coef_edema: 0.6319 - val_dice_coef_enhancing: 0.5610 - lr: 1.0000e-04
# Epoch 14/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0177 - mean_io_u: 0.8162 - dice_coef: 0.5290 - precision: 0.9949 - sensitivity: 0.9920 - specificity: 0.9983 - dice_loss: 0.4710 - dice_normal: 0.9988 - dice_coef_necrotic: 0.4116 - dice_coef_edema: 0.6571 - dice_coef_enhancing: 0.5977
# Epoch 14: val_dice_loss improved from 0.49229 to 0.47587, saving model to model_weights.h5
# 249/249 [==============================] - 224s 899ms/step - loss: 0.0177 - mean_io_u: 0.8162 - dice_coef: 0.5290 - precision: 0.9949 - sensitivity: 0.9920 - specificity: 0.9983 - dice_loss: 0.4710 - dice_normal: 0.9988 - dice_coef_necrotic: 0.4116 - dice_coef_edema: 0.6571 - dice_coef_enhancing: 0.5977 - val_loss: 0.0153 - val_mean_io_u: 0.8136 - val_dice_coef: 0.5241 - val_precision: 0.9958 - val_sensitivity: 0.9936 - val_specificity: 0.9986 - val_dice_loss: 0.4759 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4189 - val_dice_coef_edema: 0.6565 - val_dice_coef_enhancing: 0.5815 - lr: 1.0000e-04
# Epoch 15/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0174 - mean_io_u: 0.8103 - dice_coef: 0.5359 - precision: 0.9950 - sensitivity: 0.9921 - specificity: 0.9983 - dice_loss: 0.4641 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4244 - dice_coef_edema: 0.6659 - dice_coef_enhancing: 0.6119
# Epoch 15: val_dice_loss improved from 0.47587 to 0.47334, saving model to model_weights.h5
# 249/249 [==============================] - 224s 896ms/step - loss: 0.0174 - mean_io_u: 0.8103 - dice_coef: 0.5359 - precision: 0.9950 - sensitivity: 0.9921 - specificity: 0.9983 - dice_loss: 0.4641 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4244 - dice_coef_edema: 0.6659 - dice_coef_enhancing: 0.6119 - val_loss: 0.0154 - val_mean_io_u: 0.8272 - val_dice_coef: 0.5267 - val_precision: 0.9958 - val_sensitivity: 0.9936 - val_specificity: 0.9986 - val_dice_loss: 0.4733 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4333 - val_dice_coef_edema: 0.6537 - val_dice_coef_enhancing: 0.5767 - lr: 1.0000e-04
# Epoch 16/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.8247 - dice_coef: 0.5481 - precision: 0.9951 - sensitivity: 0.9925 - specificity: 0.9983 - dice_loss: 0.4519 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4552 - dice_coef_edema: 0.6749 - dice_coef_enhancing: 0.6234
# Epoch 16: val_dice_loss did not improve from 0.47334
# 249/249 [==============================] - 225s 902ms/step - loss: 0.0167 - mean_io_u: 0.8247 - dice_coef: 0.5481 - precision: 0.9951 - sensitivity: 0.9925 - specificity: 0.9983 - dice_loss: 0.4519 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4552 - dice_coef_edema: 0.6749 - dice_coef_enhancing: 0.6234 - val_loss: 0.0165 - val_mean_io_u: 0.8143 - val_dice_coef: 0.5228 - val_precision: 0.9958 - val_sensitivity: 0.9930 - val_specificity: 0.9986 - val_dice_loss: 0.4772 - val_dice_normal: 0.9989 - val_dice_coef_necrotic: 0.4341 - val_dice_coef_edema: 0.6384 - val_dice_coef_enhancing: 0.5971 - lr: 1.0000e-04
# Epoch 17/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.8241 - dice_coef: 0.5526 - precision: 0.9952 - sensitivity: 0.9926 - specificity: 0.9984 - dice_loss: 0.4474 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4650 - dice_coef_edema: 0.6782 - dice_coef_enhancing: 0.6285
# Epoch 17: val_dice_loss improved from 0.47334 to 0.46198, saving model to model_weights.h5
# 249/249 [==============================] - 224s 897ms/step - loss: 0.0165 - mean_io_u: 0.8241 - dice_coef: 0.5526 - precision: 0.9952 - sensitivity: 0.9926 - specificity: 0.9984 - dice_loss: 0.4474 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4650 - dice_coef_edema: 0.6782 - dice_coef_enhancing: 0.6285 - val_loss: 0.0149 - val_mean_io_u: 0.8285 - val_dice_coef: 0.5380 - val_precision: 0.9959 - val_sensitivity: 0.9940 - val_specificity: 0.9986 - val_dice_loss: 0.4620 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4079 - val_dice_coef_edema: 0.6952 - val_dice_coef_enhancing: 0.5875 - lr: 1.0000e-04
# Epoch 18/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0159 - mean_io_u: 0.8284 - dice_coef: 0.5643 - precision: 0.9954 - sensitivity: 0.9929 - specificity: 0.9984 - dice_loss: 0.4357 - dice_normal: 0.9990 - dice_coef_necrotic: 0.4855 - dice_coef_edema: 0.6950 - dice_coef_enhancing: 0.6422
# Epoch 18: val_dice_loss did not improve from 0.46198
# 249/249 [==============================] - 220s 884ms/step - loss: 0.0159 - mean_io_u: 0.8284 - dice_coef: 0.5643 - precision: 0.9954 - sensitivity: 0.9929 - specificity: 0.9984 - dice_loss: 0.4357 - dice_normal: 0.9990 - dice_coef_necrotic: 0.4855 - dice_coef_edema: 0.6950 - dice_coef_enhancing: 0.6422 - val_loss: 0.0153 - val_mean_io_u: 0.8368 - val_dice_coef: 0.5320 - val_precision: 0.9960 - val_sensitivity: 0.9935 - val_specificity: 0.9986 - val_dice_loss: 0.4680 - val_dice_normal: 0.9989 - val_dice_coef_necrotic: 0.4376 - val_dice_coef_edema: 0.6808 - val_dice_coef_enhancing: 0.6077 - lr: 1.0000e-04
# Epoch 19/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0161 - mean_io_u: 0.8487 - dice_coef: 0.5623 - precision: 0.9953 - sensitivity: 0.9929 - specificity: 0.9984 - dice_loss: 0.4377 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4761 - dice_coef_edema: 0.6922 - dice_coef_enhancing: 0.6397
# Epoch 19: val_dice_loss improved from 0.46198 to 0.46000, saving model to model_weights.h5
# 249/249 [==============================] - 223s 895ms/step - loss: 0.0161 - mean_io_u: 0.8487 - dice_coef: 0.5623 - precision: 0.9953 - sensitivity: 0.9929 - specificity: 0.9984 - dice_loss: 0.4377 - dice_normal: 0.9989 - dice_coef_necrotic: 0.4761 - dice_coef_edema: 0.6922 - dice_coef_enhancing: 0.6397 - val_loss: 0.0154 - val_mean_io_u: 0.8451 - val_dice_coef: 0.5400 - val_precision: 0.9960 - val_sensitivity: 0.9940 - val_specificity: 0.9986 - val_dice_loss: 0.4600 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4229 - val_dice_coef_edema: 0.6809 - val_dice_coef_enhancing: 0.6158 - lr: 1.0000e-04
# Epoch 20/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0151 - mean_io_u: 0.8496 - dice_coef: 0.5766 - precision: 0.9954 - sensitivity: 0.9932 - specificity: 0.9984 - dice_loss: 0.4234 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5012 - dice_coef_edema: 0.7102 - dice_coef_enhancing: 0.6538
# Epoch 20: val_dice_loss improved from 0.46000 to 0.45228, saving model to model_weights.h5
# 249/249 [==============================] - 226s 908ms/step - loss: 0.0151 - mean_io_u: 0.8496 - dice_coef: 0.5766 - precision: 0.9954 - sensitivity: 0.9932 - specificity: 0.9984 - dice_loss: 0.4234 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5012 - dice_coef_edema: 0.7102 - dice_coef_enhancing: 0.6538 - val_loss: 0.0146 - val_mean_io_u: 0.8368 - val_dice_coef: 0.5477 - val_precision: 0.9959 - val_sensitivity: 0.9938 - val_specificity: 0.9986 - val_dice_loss: 0.4523 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4678 - val_dice_coef_edema: 0.6994 - val_dice_coef_enhancing: 0.6026 - lr: 1.0000e-04
# Epoch 21/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0147 - mean_io_u: 0.8497 - dice_coef: 0.5815 - precision: 0.9955 - sensitivity: 0.9934 - specificity: 0.9985 - dice_loss: 0.4185 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5189 - dice_coef_edema: 0.7172 - dice_coef_enhancing: 0.6524
# Epoch 21: val_dice_loss improved from 0.45228 to 0.45134, saving model to model_weights.h5
# 249/249 [==============================] - 223s 896ms/step - loss: 0.0147 - mean_io_u: 0.8497 - dice_coef: 0.5815 - precision: 0.9955 - sensitivity: 0.9934 - specificity: 0.9985 - dice_loss: 0.4185 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5189 - dice_coef_edema: 0.7172 - dice_coef_enhancing: 0.6524 - val_loss: 0.0139 - val_mean_io_u: 0.8492 - val_dice_coef: 0.5487 - val_precision: 0.9960 - val_sensitivity: 0.9941 - val_specificity: 0.9986 - val_dice_loss: 0.4513 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.4135 - val_dice_coef_edema: 0.7095 - val_dice_coef_enhancing: 0.6258 - lr: 1.0000e-04
# Epoch 22/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0144 - mean_io_u: 0.8566 - dice_coef: 0.5890 - precision: 0.9956 - sensitivity: 0.9936 - specificity: 0.9985 - dice_loss: 0.4110 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5260 - dice_coef_edema: 0.7197 - dice_coef_enhancing: 0.6675
# Epoch 22: val_dice_loss improved from 0.45134 to 0.43787, saving model to model_weights.h5
# 249/249 [==============================] - 252s 1s/step - loss: 0.0144 - mean_io_u: 0.8566 - dice_coef: 0.5890 - precision: 0.9956 - sensitivity: 0.9936 - specificity: 0.9985 - dice_loss: 0.4110 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5260 - dice_coef_edema: 0.7197 - dice_coef_enhancing: 0.6675 - val_loss: 0.0140 - val_mean_io_u: 0.8574 - val_dice_coef: 0.5621 - val_precision: 0.9958 - val_sensitivity: 0.9942 - val_specificity: 0.9986 - val_dice_loss: 0.4379 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4668 - val_dice_coef_edema: 0.7078 - val_dice_coef_enhancing: 0.6176 - lr: 1.0000e-04
# Epoch 23/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0142 - mean_io_u: 0.8574 - dice_coef: 0.5922 - precision: 0.9957 - sensitivity: 0.9936 - specificity: 0.9985 - dice_loss: 0.4078 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5369 - dice_coef_edema: 0.7271 - dice_coef_enhancing: 0.6550
# Epoch 23: val_dice_loss improved from 0.43787 to 0.43526, saving model to model_weights.h5
# 249/249 [==============================] - 222s 892ms/step - loss: 0.0142 - mean_io_u: 0.8574 - dice_coef: 0.5922 - precision: 0.9957 - sensitivity: 0.9936 - specificity: 0.9985 - dice_loss: 0.4078 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5369 - dice_coef_edema: 0.7271 - dice_coef_enhancing: 0.6550 - val_loss: 0.0144 - val_mean_io_u: 0.8509 - val_dice_coef: 0.5647 - val_precision: 0.9959 - val_sensitivity: 0.9941 - val_specificity: 0.9986 - val_dice_loss: 0.4353 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4847 - val_dice_coef_edema: 0.7125 - val_dice_coef_enhancing: 0.6218 - lr: 1.0000e-04
# Epoch 24/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0140 - mean_io_u: 0.8612 - dice_coef: 0.5966 - precision: 0.9957 - sensitivity: 0.9938 - specificity: 0.9985 - dice_loss: 0.4034 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5453 - dice_coef_edema: 0.7286 - dice_coef_enhancing: 0.6725
# Epoch 24: val_dice_loss did not improve from 0.43526
# 249/249 [==============================] - 250s 1s/step - loss: 0.0140 - mean_io_u: 0.8612 - dice_coef: 0.5966 - precision: 0.9957 - sensitivity: 0.9938 - specificity: 0.9985 - dice_loss: 0.4034 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5453 - dice_coef_edema: 0.7286 - dice_coef_enhancing: 0.6725 - val_loss: 0.0143 - val_mean_io_u: 0.8675 - val_dice_coef: 0.5623 - val_precision: 0.9961 - val_sensitivity: 0.9941 - val_specificity: 0.9987 - val_dice_loss: 0.4377 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4850 - val_dice_coef_edema: 0.6806 - val_dice_coef_enhancing: 0.6297 - lr: 1.0000e-04
# Epoch 25/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0137 - mean_io_u: 0.8638 - dice_coef: 0.6036 - precision: 0.9957 - sensitivity: 0.9938 - specificity: 0.9985 - dice_loss: 0.3964 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5623 - dice_coef_edema: 0.7338 - dice_coef_enhancing: 0.6758
# Epoch 25: val_dice_loss improved from 0.43526 to 0.42156, saving model to model_weights.h5
# 249/249 [==============================] - 221s 888ms/step - loss: 0.0137 - mean_io_u: 0.8638 - dice_coef: 0.6036 - precision: 0.9957 - sensitivity: 0.9938 - specificity: 0.9985 - dice_loss: 0.3964 - dice_normal: 0.9991 - dice_coef_necrotic: 0.5623 - dice_coef_edema: 0.7338 - dice_coef_enhancing: 0.6758 - val_loss: 0.0139 - val_mean_io_u: 0.8653 - val_dice_coef: 0.5784 - val_precision: 0.9959 - val_sensitivity: 0.9945 - val_specificity: 0.9986 - val_dice_loss: 0.4216 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.4867 - val_dice_coef_edema: 0.7157 - val_dice_coef_enhancing: 0.6201 - lr: 1.0000e-04
# Epoch 26/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0133 - mean_io_u: 0.8647 - dice_coef: 0.6107 - precision: 0.9958 - sensitivity: 0.9940 - specificity: 0.9986 - dice_loss: 0.3893 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5750 - dice_coef_edema: 0.7441 - dice_coef_enhancing: 0.6752
# Epoch 26: val_dice_loss did not improve from 0.42156
# 249/249 [==============================] - 219s 879ms/step - loss: 0.0133 - mean_io_u: 0.8647 - dice_coef: 0.6107 - precision: 0.9958 - sensitivity: 0.9940 - specificity: 0.9986 - dice_loss: 0.3893 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5750 - dice_coef_edema: 0.7441 - dice_coef_enhancing: 0.6752 - val_loss: 0.0144 - val_mean_io_u: 0.8654 - val_dice_coef: 0.5777 - val_precision: 0.9956 - val_sensitivity: 0.9946 - val_specificity: 0.9985 - val_dice_loss: 0.4223 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.4518 - val_dice_coef_edema: 0.7340 - val_dice_coef_enhancing: 0.5947 - lr: 1.0000e-04
# Epoch 27/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0132 - mean_io_u: 0.8642 - dice_coef: 0.6120 - precision: 0.9958 - sensitivity: 0.9941 - specificity: 0.9986 - dice_loss: 0.3880 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5748 - dice_coef_edema: 0.7446 - dice_coef_enhancing: 0.6809
# Epoch 27: val_dice_loss improved from 0.42156 to 0.41770, saving model to model_weights.h5
# 249/249 [==============================] - 222s 893ms/step - loss: 0.0132 - mean_io_u: 0.8642 - dice_coef: 0.6120 - precision: 0.9958 - sensitivity: 0.9941 - specificity: 0.9986 - dice_loss: 0.3880 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5748 - dice_coef_edema: 0.7446 - dice_coef_enhancing: 0.6809 - val_loss: 0.0143 - val_mean_io_u: 0.8656 - val_dice_coef: 0.5823 - val_precision: 0.9957 - val_sensitivity: 0.9945 - val_specificity: 0.9986 - val_dice_loss: 0.4177 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4892 - val_dice_coef_edema: 0.7245 - val_dice_coef_enhancing: 0.6279 - lr: 1.0000e-04
# Epoch 28/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0130 - mean_io_u: 0.8639 - dice_coef: 0.6183 - precision: 0.9959 - sensitivity: 0.9942 - specificity: 0.9986 - dice_loss: 0.3817 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5836 - dice_coef_edema: 0.7516 - dice_coef_enhancing: 0.6861
# Epoch 28: val_dice_loss did not improve from 0.41770
# 249/249 [==============================] - 231s 926ms/step - loss: 0.0130 - mean_io_u: 0.8639 - dice_coef: 0.6183 - precision: 0.9959 - sensitivity: 0.9942 - specificity: 0.9986 - dice_loss: 0.3817 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5836 - dice_coef_edema: 0.7516 - dice_coef_enhancing: 0.6861 - val_loss: 0.0159 - val_mean_io_u: 0.8654 - val_dice_coef: 0.5678 - val_precision: 0.9955 - val_sensitivity: 0.9945 - val_specificity: 0.9985 - val_dice_loss: 0.4322 - val_dice_normal: 0.9989 - val_dice_coef_necrotic: 0.4304 - val_dice_coef_edema: 0.6840 - val_dice_coef_enhancing: 0.5827 - lr: 1.0000e-04
# Epoch 29/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0126 - mean_io_u: 0.8690 - dice_coef: 0.6234 - precision: 0.9960 - sensitivity: 0.9943 - specificity: 0.9986 - dice_loss: 0.3766 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5910 - dice_coef_edema: 0.7563 - dice_coef_enhancing: 0.6929
# Epoch 29: val_dice_loss improved from 0.41770 to 0.41640, saving model to model_weights.h5
# 249/249 [==============================] - 231s 928ms/step - loss: 0.0126 - mean_io_u: 0.8690 - dice_coef: 0.6234 - precision: 0.9960 - sensitivity: 0.9943 - specificity: 0.9986 - dice_loss: 0.3766 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5910 - dice_coef_edema: 0.7563 - dice_coef_enhancing: 0.6929 - val_loss: 0.0141 - val_mean_io_u: 0.8651 - val_dice_coef: 0.5836 - val_precision: 0.9957 - val_sensitivity: 0.9945 - val_specificity: 0.9986 - val_dice_loss: 0.4164 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4841 - val_dice_coef_edema: 0.7151 - val_dice_coef_enhancing: 0.6348 - lr: 1.0000e-04
# Epoch 30/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0124 - mean_io_u: 0.8685 - dice_coef: 0.6294 - precision: 0.9960 - sensitivity: 0.9944 - specificity: 0.9986 - dice_loss: 0.3706 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5979 - dice_coef_edema: 0.7628 - dice_coef_enhancing: 0.6999
# Epoch 30: val_dice_loss improved from 0.41640 to 0.41549, saving model to model_weights.h5
# 249/249 [==============================] - 230s 921ms/step - loss: 0.0124 - mean_io_u: 0.8685 - dice_coef: 0.6294 - precision: 0.9960 - sensitivity: 0.9944 - specificity: 0.9986 - dice_loss: 0.3706 - dice_normal: 0.9992 - dice_coef_necrotic: 0.5979 - dice_coef_edema: 0.7628 - dice_coef_enhancing: 0.6999 - val_loss: 0.0152 - val_mean_io_u: 0.8657 - val_dice_coef: 0.5845 - val_precision: 0.9956 - val_sensitivity: 0.9948 - val_specificity: 0.9985 - val_dice_loss: 0.4155 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4518 - val_dice_coef_edema: 0.7290 - val_dice_coef_enhancing: 0.6106 - lr: 1.0000e-04
# Epoch 31/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0121 - mean_io_u: 0.8687 - dice_coef: 0.6344 - precision: 0.9961 - sensitivity: 0.9945 - specificity: 0.9987 - dice_loss: 0.3656 - dice_normal: 0.9992 - dice_coef_necrotic: 0.6108 - dice_coef_edema: 0.7662 - dice_coef_enhancing: 0.7027
# Epoch 31: val_dice_loss improved from 0.41549 to 0.41139, saving model to model_weights.h5
# 249/249 [==============================] - 229s 919ms/step - loss: 0.0121 - mean_io_u: 0.8687 - dice_coef: 0.6344 - precision: 0.9961 - sensitivity: 0.9945 - specificity: 0.9987 - dice_loss: 0.3656 - dice_normal: 0.9992 - dice_coef_necrotic: 0.6108 - dice_coef_edema: 0.7662 - dice_coef_enhancing: 0.7027 - val_loss: 0.0147 - val_mean_io_u: 0.8668 - val_dice_coef: 0.5886 - val_precision: 0.9958 - val_sensitivity: 0.9946 - val_specificity: 0.9986 - val_dice_loss: 0.4114 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4905 - val_dice_coef_edema: 0.7166 - val_dice_coef_enhancing: 0.6520 - lr: 1.0000e-04
# Epoch 32/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0118 - mean_io_u: 0.8710 - dice_coef: 0.6400 - precision: 0.9961 - sensitivity: 0.9947 - specificity: 0.9987 - dice_loss: 0.3600 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6123 - dice_coef_edema: 0.7721 - dice_coef_enhancing: 0.7134
# Epoch 33: val_dice_loss improved from 0.40663 to 0.40362, saving model to model_weights.h5
# 249/249 [==============================] - 228s 915ms/step - loss: 0.0118 - mean_io_u: 0.8710 - dice_coef: 0.6400 - precision: 0.9961 - sensitivity: 0.9947 - specificity: 0.9987 - dice_loss: 0.3600 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6123 - dice_coef_edema: 0.7721 - dice_coef_enhancing: 0.7134 - val_loss: 0.0138 - val_mean_io_u: 0.8644 - val_dice_coef: 0.5964 - val_precision: 0.9958 - val_sensitivity: 0.9945 - val_specificity: 0.9986 - val_dice_loss: 0.4036 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.5076 - val_dice_coef_edema: 0.7478 - val_dice_coef_enhancing: 0.6442 - lr: 1.0000e-04
# Epoch 34/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0120 - mean_io_u: 0.8706 - dice_coef: 0.6397 - precision: 0.9961 - sensitivity: 0.9946 - specificity: 0.9987 - dice_loss: 0.3603 - dice_normal: 0.9992 - dice_coef_necrotic: 0.6194 - dice_coef_edema: 0.7687 - dice_coef_enhancing: 0.7092
# Epoch 34: val_dice_loss did not improve from 0.40362
# 249/249 [==============================] - 220s 881ms/step - loss: 0.0120 - mean_io_u: 0.8706 - dice_coef: 0.6397 - precision: 0.9961 - sensitivity: 0.9946 - specificity: 0.9987 - dice_loss: 0.3603 - dice_normal: 0.9992 - dice_coef_necrotic: 0.6194 - dice_coef_edema: 0.7687 - dice_coef_enhancing: 0.7092 - val_loss: 0.0151 - val_mean_io_u: 0.8668 - val_dice_coef: 0.5949 - val_precision: 0.9954 - val_sensitivity: 0.9945 - val_specificity: 0.9985 - val_dice_loss: 0.4051 - val_dice_normal: 0.9989 - val_dice_coef_necrotic: 0.5058 - val_dice_coef_edema: 0.7325 - val_dice_coef_enhancing: 0.6224 - lr: 1.0000e-04
# Epoch 35/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0113 - mean_io_u: 0.8730 - dice_coef: 0.6486 - precision: 0.9962 - sensitivity: 0.9949 - specificity: 0.9987 - dice_loss: 0.3514 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6277 - dice_coef_edema: 0.7838 - dice_coef_enhancing: 0.7175
# Epoch 35: val_dice_loss improved from 0.40362 to 0.39961, saving model to model_weights.h5
# 249/249 [==============================] - 220s 883ms/step - loss: 0.0113 - mean_io_u: 0.8730 - dice_coef: 0.6486 - precision: 0.9962 - sensitivity: 0.9949 - specificity: 0.9987 - dice_loss: 0.3514 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6277 - dice_coef_edema: 0.7838 - dice_coef_enhancing: 0.7175 - val_loss: 0.0144 - val_mean_io_u: 0.8694 - val_dice_coef: 0.6004 - val_precision: 0.9958 - val_sensitivity: 0.9946 - val_specificity: 0.9986 - val_dice_loss: 0.3996 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5083 - val_dice_coef_edema: 0.7217 - val_dice_coef_enhancing: 0.6569 - lr: 1.0000e-04
# Epoch 36/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0114 - mean_io_u: 0.8715 - dice_coef: 0.6492 - precision: 0.9962 - sensitivity: 0.9948 - specificity: 0.9987 - dice_loss: 0.3508 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6330 - dice_coef_edema: 0.7808 - dice_coef_enhancing: 0.7161
# Epoch 36: val_dice_loss did not improve from 0.39961
# 249/249 [==============================] - 219s 881ms/step - loss: 0.0114 - mean_io_u: 0.8715 - dice_coef: 0.6492 - precision: 0.9962 - sensitivity: 0.9948 - specificity: 0.9987 - dice_loss: 0.3508 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6330 - dice_coef_edema: 0.7808 - dice_coef_enhancing: 0.7161 - val_loss: 0.0142 - val_mean_io_u: 0.8677 - val_dice_coef: 0.5980 - val_precision: 0.9960 - val_sensitivity: 0.9948 - val_specificity: 0.9986 - val_dice_loss: 0.4020 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.5092 - val_dice_coef_edema: 0.7023 - val_dice_coef_enhancing: 0.6537 - lr: 1.0000e-04
# Epoch 37/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0107 - mean_io_u: 0.8776 - dice_coef: 0.6626 - precision: 0.9964 - sensitivity: 0.9951 - specificity: 0.9988 - dice_loss: 0.3374 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6474 - dice_coef_edema: 0.7966 - dice_coef_enhancing: 0.7251
# Epoch 37: val_dice_loss improved from 0.39961 to 0.39592, saving model to model_weights.h5
# 249/249 [==============================] - 219s 880ms/step - loss: 0.0107 - mean_io_u: 0.8776 - dice_coef: 0.6626 - precision: 0.9964 - sensitivity: 0.9951 - specificity: 0.9988 - dice_loss: 0.3374 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6474 - dice_coef_edema: 0.7966 - dice_coef_enhancing: 0.7251 - val_loss: 0.0145 - val_mean_io_u: 0.8630 - val_dice_coef: 0.6041 - val_precision: 0.9956 - val_sensitivity: 0.9946 - val_specificity: 0.9985 - val_dice_loss: 0.3959 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.4988 - val_dice_coef_edema: 0.7507 - val_dice_coef_enhancing: 0.6490 - lr: 1.0000e-04
# Epoch 38/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0105 - mean_io_u: 0.8773 - dice_coef: 0.6648 - precision: 0.9964 - sensitivity: 0.9952 - specificity: 0.9988 - dice_loss: 0.3352 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6613 - dice_coef_edema: 0.7967 - dice_coef_enhancing: 0.7304
# Epoch 38: val_dice_loss improved from 0.39592 to 0.38495, saving model to model_weights.h5
# 249/249 [==============================] - 224s 900ms/step - loss: 0.0105 - mean_io_u: 0.8773 - dice_coef: 0.6648 - precision: 0.9964 - sensitivity: 0.9952 - specificity: 0.9988 - dice_loss: 0.3352 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6613 - dice_coef_edema: 0.7967 - dice_coef_enhancing: 0.7304 - val_loss: 0.0150 - val_mean_io_u: 0.8781 - val_dice_coef: 0.6150 - val_precision: 0.9958 - val_sensitivity: 0.9949 - val_specificity: 0.9986 - val_dice_loss: 0.3850 - val_dice_normal: 0.9990 - val_dice_coef_necrotic: 0.5167 - val_dice_coef_edema: 0.7449 - val_dice_coef_enhancing: 0.6445 - lr: 1.0000e-04
# Epoch 39/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0104 - mean_io_u: 0.8779 - dice_coef: 0.6668 - precision: 0.9964 - sensitivity: 0.9952 - specificity: 0.9988 - dice_loss: 0.3332 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6571 - dice_coef_edema: 0.8016 - dice_coef_enhancing: 0.7290
# Epoch 39: val_dice_loss improved from 0.38495 to 0.38280, saving model to model_weights.h5
# 249/249 [==============================] - 219s 877ms/step - loss: 0.0104 - mean_io_u: 0.8779 - dice_coef: 0.6668 - precision: 0.9964 - sensitivity: 0.9952 - specificity: 0.9988 - dice_loss: 0.3332 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6571 - dice_coef_edema: 0.8016 - dice_coef_enhancing: 0.7290 - val_loss: 0.0139 - val_mean_io_u: 0.8675 - val_dice_coef: 0.6172 - val_precision: 0.9959 - val_sensitivity: 0.9950 - val_specificity: 0.9986 - val_dice_loss: 0.3828 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5130 - val_dice_coef_edema: 0.7561 - val_dice_coef_enhancing: 0.6506 - lr: 1.0000e-04
# Epoch 40/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0103 - mean_io_u: 0.8793 - dice_coef: 0.6711 - precision: 0.9965 - sensitivity: 0.9953 - specificity: 0.9988 - dice_loss: 0.3289 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6681 - dice_coef_edema: 0.8060 - dice_coef_enhancing: 0.7315
# Epoch 40: val_dice_loss did not improve from 0.38280
# 249/249 [==============================] - 223s 896ms/step - loss: 0.0103 - mean_io_u: 0.8793 - dice_coef: 0.6711 - precision: 0.9965 - sensitivity: 0.9953 - specificity: 0.9988 - dice_loss: 0.3289 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6681 - dice_coef_edema: 0.8060 - dice_coef_enhancing: 0.7315 - val_loss: 0.0171 - val_mean_io_u: 0.8859 - val_dice_coef: 0.5960 - val_precision: 0.9955 - val_sensitivity: 0.9947 - val_specificity: 0.9985 - val_dice_loss: 0.4040 - val_dice_normal: 0.9989 - val_dice_coef_necrotic: 0.4400 - val_dice_coef_edema: 0.6855 - val_dice_coef_enhancing: 0.6474 - lr: 1.0000e-04
# Epoch 41/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0107 - mean_io_u: 0.8755 - dice_coef: 0.6666 - precision: 0.9964 - sensitivity: 0.9951 - specificity: 0.9988 - dice_loss: 0.3334 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6504 - dice_coef_edema: 0.7932 - dice_coef_enhancing: 0.7403
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 41: val_dice_loss did not improve from 0.38280
# 249/249 [==============================] - 220s 882ms/step - loss: 0.0107 - mean_io_u: 0.8755 - dice_coef: 0.6666 - precision: 0.9964 - sensitivity: 0.9951 - specificity: 0.9988 - dice_loss: 0.3334 - dice_normal: 0.9993 - dice_coef_necrotic: 0.6504 - dice_coef_edema: 0.7932 - dice_coef_enhancing: 0.7403 - val_loss: 0.0139 - val_mean_io_u: 0.8672 - val_dice_coef: 0.6023 - val_precision: 0.9959 - val_sensitivity: 0.9947 - val_specificity: 0.9986 - val_dice_loss: 0.3977 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5105 - val_dice_coef_edema: 0.7199 - val_dice_coef_enhancing: 0.6654 - lr: 1.0000e-04
# Epoch 42/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0096 - mean_io_u: 0.8726 - dice_coef: 0.6801 - precision: 0.9967 - sensitivity: 0.9956 - specificity: 0.9989 - dice_loss: 0.3199 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6865 - dice_coef_edema: 0.8192 - dice_coef_enhancing: 0.7443
# Epoch 42: val_dice_loss did not improve from 0.38280
# 249/249 [==============================] - 221s 886ms/step - loss: 0.0096 - mean_io_u: 0.8726 - dice_coef: 0.6801 - precision: 0.9967 - sensitivity: 0.9956 - specificity: 0.9989 - dice_loss: 0.3199 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6865 - dice_coef_edema: 0.8192 - dice_coef_enhancing: 0.7443 - val_loss: 0.0137 - val_mean_io_u: 0.8761 - val_dice_coef: 0.6168 - val_precision: 0.9959 - val_sensitivity: 0.9950 - val_specificity: 0.9986 - val_dice_loss: 0.3832 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5136 - val_dice_coef_edema: 0.7403 - val_dice_coef_enhancing: 0.6588 - lr: 1.0000e-05
# Epoch 43/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0091 - mean_io_u: 0.8802 - dice_coef: 0.6896 - precision: 0.9968 - sensitivity: 0.9958 - specificity: 0.9989 - dice_loss: 0.3104 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6974 - dice_coef_edema: 0.8289 - dice_coef_enhancing: 0.7512
# Epoch 43: val_dice_loss improved from 0.38280 to 0.38017, saving model to model_weights.h5
# 249/249 [==============================] - 223s 896ms/step - loss: 0.0091 - mean_io_u: 0.8802 - dice_coef: 0.6896 - precision: 0.9968 - sensitivity: 0.9958 - specificity: 0.9989 - dice_loss: 0.3104 - dice_normal: 0.9994 - dice_coef_necrotic: 0.6974 - dice_coef_edema: 0.8289 - dice_coef_enhancing: 0.7512 - val_loss: 0.0140 - val_mean_io_u: 0.8824 - val_dice_coef: 0.6198 - val_precision: 0.9959 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3802 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5099 - val_dice_coef_edema: 0.7479 - val_dice_coef_enhancing: 0.6541 - lr: 1.0000e-05
# Epoch 44/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0089 - mean_io_u: 0.8854 - dice_coef: 0.6937 - precision: 0.9968 - sensitivity: 0.9958 - specificity: 0.9989 - dice_loss: 0.3063 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7016 - dice_coef_edema: 0.8321 - dice_coef_enhancing: 0.7536
# Epoch 44: val_dice_loss did not improve from 0.38017
# 249/249 [==============================] - 219s 879ms/step - loss: 0.0089 - mean_io_u: 0.8854 - dice_coef: 0.6937 - precision: 0.9968 - sensitivity: 0.9958 - specificity: 0.9989 - dice_loss: 0.3063 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7016 - dice_coef_edema: 0.8321 - dice_coef_enhancing: 0.7536 - val_loss: 0.0142 - val_mean_io_u: 0.8854 - val_dice_coef: 0.6198 - val_precision: 0.9959 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3802 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5070 - val_dice_coef_edema: 0.7460 - val_dice_coef_enhancing: 0.6573 - lr: 1.0000e-05
# Epoch 45/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0088 - mean_io_u: 0.8889 - dice_coef: 0.6971 - precision: 0.9968 - sensitivity: 0.9959 - specificity: 0.9989 - dice_loss: 0.3029 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7039 - dice_coef_edema: 0.8352 - dice_coef_enhancing: 0.7568
# Epoch 45: val_dice_loss improved from 0.38017 to 0.37822, saving model to model_weights.h5
# 249/249 [==============================] - 220s 883ms/step - loss: 0.0088 - mean_io_u: 0.8889 - dice_coef: 0.6971 - precision: 0.9968 - sensitivity: 0.9959 - specificity: 0.9989 - dice_loss: 0.3029 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7039 - dice_coef_edema: 0.8352 - dice_coef_enhancing: 0.7568 - val_loss: 0.0143 - val_mean_io_u: 0.8892 - val_dice_coef: 0.6218 - val_precision: 0.9959 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3782 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5108 - val_dice_coef_edema: 0.7460 - val_dice_coef_enhancing: 0.6557 - lr: 1.0000e-05
# Epoch 46/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0087 - mean_io_u: 0.8925 - dice_coef: 0.7001 - precision: 0.9968 - sensitivity: 0.9959 - specificity: 0.9989 - dice_loss: 0.2999 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7079 - dice_coef_edema: 0.8366 - dice_coef_enhancing: 0.7581
# Epoch 46: val_dice_loss did not improve from 0.37822
# 249/249 [==============================] - 216s 868ms/step - loss: 0.0087 - mean_io_u: 0.8925 - dice_coef: 0.7001 - precision: 0.9968 - sensitivity: 0.9959 - specificity: 0.9989 - dice_loss: 0.2999 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7079 - dice_coef_edema: 0.8366 - dice_coef_enhancing: 0.7581 - val_loss: 0.0146 - val_mean_io_u: 0.8910 - val_dice_coef: 0.6200 - val_precision: 0.9959 - val_sensitivity: 0.9950 - val_specificity: 0.9986 - val_dice_loss: 0.3800 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5083 - val_dice_coef_edema: 0.7389 - val_dice_coef_enhancing: 0.6579 - lr: 1.0000e-05
# Epoch 47/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0086 - mean_io_u: 0.8934 - dice_coef: 0.7025 - precision: 0.9969 - sensitivity: 0.9960 - specificity: 0.9989 - dice_loss: 0.2975 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7111 - dice_coef_edema: 0.8391 - dice_coef_enhancing: 0.7611
# Epoch 47: val_dice_loss improved from 0.37822 to 0.37759, saving model to model_weights.h5
# 249/249 [==============================] - 221s 889ms/step - loss: 0.0086 - mean_io_u: 0.8934 - dice_coef: 0.7025 - precision: 0.9969 - sensitivity: 0.9960 - specificity: 0.9989 - dice_loss: 0.2975 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7111 - dice_coef_edema: 0.8391 - dice_coef_enhancing: 0.7611 - val_loss: 0.0147 - val_mean_io_u: 0.8936 - val_dice_coef: 0.6224 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3776 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5112 - val_dice_coef_edema: 0.7430 - val_dice_coef_enhancing: 0.6584 - lr: 1.0000e-05
# Epoch 48/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0085 - mean_io_u: 0.8954 - dice_coef: 0.7038 - precision: 0.9969 - sensitivity: 0.9960 - specificity: 0.9989 - dice_loss: 0.2962 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7125 - dice_coef_edema: 0.8403 - dice_coef_enhancing: 0.7616
# Epoch 48: val_dice_loss improved from 0.37759 to 0.37591, saving model to model_weights.h5
# 249/249 [==============================] - 219s 879ms/step - loss: 0.0085 - mean_io_u: 0.8954 - dice_coef: 0.7038 - precision: 0.9969 - sensitivity: 0.9960 - specificity: 0.9989 - dice_loss: 0.2962 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7125 - dice_coef_edema: 0.8403 - dice_coef_enhancing: 0.7616 - val_loss: 0.0148 - val_mean_io_u: 0.8942 - val_dice_coef: 0.6241 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3759 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5118 - val_dice_coef_edema: 0.7447 - val_dice_coef_enhancing: 0.6553 - lr: 1.0000e-05
# Epoch 49/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0085 - mean_io_u: 0.8965 - dice_coef: 0.7057 - precision: 0.9969 - sensitivity: 0.9961 - specificity: 0.9990 - dice_loss: 0.2943 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7163 - dice_coef_edema: 0.8415 - dice_coef_enhancing: 0.7625
# Epoch 49: val_dice_loss did not improve from 0.37591
# ...
# Epoch 82/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9012 - dice_coef: 0.7152 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2848 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7295 - dice_coef_edema: 0.8506 - dice_coef_enhancing: 0.7692
# Epoch 82: val_dice_loss did not improve from 0.37407
# 249/249 [==============================] - 223s 896ms/step - loss: 0.0080 - mean_io_u: 0.9012 - dice_coef: 0.7152 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2848 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7295 - dice_coef_edema: 0.8506 - dice_coef_enhancing: 0.7692 - val_loss: 0.0154 - val_mean_io_u: 0.9004 - val_dice_coef: 0.6255 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3745 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5087 - val_dice_coef_edema: 0.7391 - val_dice_coef_enhancing: 0.6568 - lr: 1.0000e-06
# Epoch 83/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9010 - dice_coef: 0.7152 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2848 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7294 - dice_coef_edema: 0.8504 - dice_coef_enhancing: 0.7694
# Epoch 83: val_dice_loss did not improve from 0.37407
# 249/249 [==============================] - 225s 903ms/step - loss: 0.0080 - mean_io_u: 0.9010 - dice_coef: 0.7152 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2848 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7294 - dice_coef_edema: 0.8504 - dice_coef_enhancing: 0.7694 - val_loss: 0.0154 - val_mean_io_u: 0.8998 - val_dice_coef: 0.6257 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3743 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5103 - val_dice_coef_edema: 0.7407 - val_dice_coef_enhancing: 0.6589 - lr: 1.0000e-06
# Epoch 84/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9013 - dice_coef: 0.7152 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2848 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7297 - dice_coef_edema: 0.8507 - dice_coef_enhancing: 0.7698
# Epoch 84: val_dice_loss improved from 0.37407 to 0.37401, saving model to model_weights.h5
# 249/249 [==============================] - 221s 887ms/step - loss: 0.0080 - mean_io_u: 0.9013 - dice_coef: 0.7152 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2848 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7297 - dice_coef_edema: 0.8507 - dice_coef_enhancing: 0.7698 - val_loss: 0.0154 - val_mean_io_u: 0.9002 - val_dice_coef: 0.6260 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3740 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5099 - val_dice_coef_edema: 0.7406 - val_dice_coef_enhancing: 0.6575 - lr: 1.0000e-06
# Epoch 85/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9014 - dice_coef: 0.7156 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2844 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7307 - dice_coef_edema: 0.8511 - dice_coef_enhancing: 0.7693
# Epoch 85: val_dice_loss did not improve from 0.37401
# 249/249 [==============================] - 223s 895ms/step - loss: 0.0080 - mean_io_u: 0.9014 - dice_coef: 0.7156 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2844 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7307 - dice_coef_edema: 0.8511 - dice_coef_enhancing: 0.7693 - val_loss: 0.0155 - val_mean_io_u: 0.9008 - val_dice_coef: 0.6256 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3744 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5092 - val_dice_coef_edema: 0.7388 - val_dice_coef_enhancing: 0.6575 - lr: 1.0000e-06
# Epoch 86/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9012 - dice_coef: 0.7155 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2845 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7296 - dice_coef_edema: 0.8509 - dice_coef_enhancing: 0.7707
# Epoch 86: val_dice_loss improved from 0.37401 to 0.37355, saving model to model_weights.h5
# 249/249 [==============================] - 216s 869ms/step - loss: 0.0080 - mean_io_u: 0.9012 - dice_coef: 0.7155 - precision: 0.9970 - sensitivity: 0.9962 - specificity: 0.9990 - dice_loss: 0.2845 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7296 - dice_coef_edema: 0.8509 - dice_coef_enhancing: 0.7707 - val_loss: 0.0154 - val_mean_io_u: 0.9003 - val_dice_coef: 0.6264 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3736 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5100 - val_dice_coef_edema: 0.7419 - val_dice_coef_enhancing: 0.6573 - lr: 1.0000e-06
# Epoch 87/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9017 - dice_coef: 0.7161 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2839 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7307 - dice_coef_edema: 0.8513 - dice_coef_enhancing: 0.7702
# Epoch 87: val_dice_loss did not improve from 0.37355
# 249/249 [==============================] - 220s 882ms/step - loss: 0.0080 - mean_io_u: 0.9017 - dice_coef: 0.7161 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2839 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7307 - dice_coef_edema: 0.8513 - dice_coef_enhancing: 0.7702 - val_loss: 0.0154 - val_mean_io_u: 0.9006 - val_dice_coef: 0.6262 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3738 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5098 - val_dice_coef_edema: 0.7409 - val_dice_coef_enhancing: 0.6572 - lr: 1.0000e-06
# Epoch 88/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9020 - dice_coef: 0.7163 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2837 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7311 - dice_coef_edema: 0.8514 - dice_coef_enhancing: 0.7702
# Epoch 88: val_dice_loss did not improve from 0.37355
# 249/249 [==============================] - 250s 1s/step - loss: 0.0080 - mean_io_u: 0.9020 - dice_coef: 0.7163 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2837 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7311 - dice_coef_edema: 0.8514 - dice_coef_enhancing: 0.7702 - val_loss: 0.0154 - val_mean_io_u: 0.9007 - val_dice_coef: 0.6261 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3739 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5096 - val_dice_coef_edema: 0.7403 - val_dice_coef_enhancing: 0.6575 - lr: 1.0000e-06
# Epoch 89/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9011 - dice_coef: 0.7161 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2839 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7310 - dice_coef_edema: 0.8516 - dice_coef_enhancing: 0.7703
# Epoch 89: val_dice_loss did not improve from 0.37355
# 249/249 [==============================] - 226s 906ms/step - loss: 0.0080 - mean_io_u: 0.9011 - dice_coef: 0.7161 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2839 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7310 - dice_coef_edema: 0.8516 - dice_coef_enhancing: 0.7703 - val_loss: 0.0154 - val_mean_io_u: 0.9006 - val_dice_coef: 0.6264 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3736 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5094 - val_dice_coef_edema: 0.7414 - val_dice_coef_enhancing: 0.6573 - lr: 1.0000e-06
# Epoch 90/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9018 - dice_coef: 0.7165 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2835 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7313 - dice_coef_edema: 0.8518 - dice_coef_enhancing: 0.7703
# Epoch 90: val_dice_loss did not improve from 0.37355
# 249/249 [==============================] - 224s 900ms/step - loss: 0.0080 - mean_io_u: 0.9018 - dice_coef: 0.7165 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2835 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7313 - dice_coef_edema: 0.8518 - dice_coef_enhancing: 0.7703 - val_loss: 0.0155 - val_mean_io_u: 0.9009 - val_dice_coef: 0.6262 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3738 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5093 - val_dice_coef_edema: 0.7408 - val_dice_coef_enhancing: 0.6575 - lr: 1.0000e-06
# Epoch 91/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9020 - dice_coef: 0.7165 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2835 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7312 - dice_coef_edema: 0.8517 - dice_coef_enhancing: 0.7708
# Epoch 91: val_dice_loss improved from 0.37355 to 0.37314, saving model to model_weights.h5
# 249/249 [==============================] - 222s 889ms/step - loss: 0.0080 - mean_io_u: 0.9020 - dice_coef: 0.7165 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2835 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7312 - dice_coef_edema: 0.8517 - dice_coef_enhancing: 0.7708 - val_loss: 0.0154 - val_mean_io_u: 0.9004 - val_dice_coef: 0.6269 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3731 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5108 - val_dice_coef_edema: 0.7428 - val_dice_coef_enhancing: 0.6583 - lr: 1.0000e-06
# Epoch 92/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9018 - dice_coef: 0.7168 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2832 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7316 - dice_coef_edema: 0.8522 - dice_coef_enhancing: 0.7705
# Epoch 92: val_dice_loss did not improve from 0.37314
# 249/249 [==============================] - 222s 890ms/step - loss: 0.0080 - mean_io_u: 0.9018 - dice_coef: 0.7168 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2832 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7316 - dice_coef_edema: 0.8522 - dice_coef_enhancing: 0.7705 - val_loss: 0.0155 - val_mean_io_u: 0.9011 - val_dice_coef: 0.6265 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3735 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5099 - val_dice_coef_edema: 0.7408 - val_dice_coef_enhancing: 0.6579 - lr: 1.0000e-06
# Epoch 93/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9020 - dice_coef: 0.7167 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2833 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7317 - dice_coef_edema: 0.8522 - dice_coef_enhancing: 0.7709
# Epoch 93: val_dice_loss did not improve from 0.37314
# 249/249 [==============================] - 223s 896ms/step - loss: 0.0080 - mean_io_u: 0.9020 - dice_coef: 0.7167 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2833 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7317 - dice_coef_edema: 0.8522 - dice_coef_enhancing: 0.7709 - val_loss: 0.0155 - val_mean_io_u: 0.9014 - val_dice_coef: 0.6268 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3732 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5104 - val_dice_coef_edema: 0.7407 - val_dice_coef_enhancing: 0.6571 - lr: 1.0000e-06
# Epoch 94/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9023 - dice_coef: 0.7173 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2827 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7320 - dice_coef_edema: 0.8524 - dice_coef_enhancing: 0.7706
# Epoch 94: val_dice_loss did not improve from 0.37314
# 249/249 [==============================] - 221s 887ms/step - loss: 0.0080 - mean_io_u: 0.9023 - dice_coef: 0.7173 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2827 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7320 - dice_coef_edema: 0.8524 - dice_coef_enhancing: 0.7706 - val_loss: 0.0155 - val_mean_io_u: 0.9008 - val_dice_coef: 0.6263 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3737 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5104 - val_dice_coef_edema: 0.7399 - val_dice_coef_enhancing: 0.6587 - lr: 1.0000e-06
# Epoch 95/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9021 - dice_coef: 0.7170 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2830 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7323 - dice_coef_edema: 0.8522 - dice_coef_enhancing: 0.7710
# Epoch 95: val_dice_loss did not improve from 0.37314
# 249/249 [==============================] - 224s 895ms/step - loss: 0.0080 - mean_io_u: 0.9021 - dice_coef: 0.7170 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2830 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7323 - dice_coef_edema: 0.8522 - dice_coef_enhancing: 0.7710 - val_loss: 0.0155 - val_mean_io_u: 0.9012 - val_dice_coef: 0.6267 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3733 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5105 - val_dice_coef_edema: 0.7405 - val_dice_coef_enhancing: 0.6583 - lr: 1.0000e-06
# Epoch 96/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0080 - mean_io_u: 0.9024 - dice_coef: 0.7174 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2826 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7324 - dice_coef_edema: 0.8525 - dice_coef_enhancing: 0.7710
# Epoch 96: val_dice_loss did not improve from 0.37314
# 249/249 [==============================] - 224s 898ms/step - loss: 0.0080 - mean_io_u: 0.9024 - dice_coef: 0.7174 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2826 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7324 - dice_coef_edema: 0.8525 - dice_coef_enhancing: 0.7710 - val_loss: 0.0155 - val_mean_io_u: 0.9010 - val_dice_coef: 0.6266 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3734 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5104 - val_dice_coef_edema: 0.7406 - val_dice_coef_enhancing: 0.6584 - lr: 1.0000e-06
# Epoch 97/1000
# 249/249 [==============================] - ETA: 0s - loss: 0.0079 - mean_io_u: 0.9023 - dice_coef: 0.7174 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2826 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7328 - dice_coef_edema: 0.8528 - dice_coef_enhancing: 0.7713
# Epoch 97: val_dice_loss did not improve from 0.37314
# 249/249 [==============================] - 223s 894ms/step - loss: 0.0079 - mean_io_u: 0.9023 - dice_coef: 0.7174 - precision: 0.9970 - sensitivity: 0.9963 - specificity: 0.9990 - dice_loss: 0.2826 - dice_normal: 0.9995 - dice_coef_necrotic: 0.7328 - dice_coef_edema: 0.8528 - dice_coef_enhancing: 0.7713 - val_loss: 0.0155 - val_mean_io_u: 0.9013 - val_dice_coef: 0.6268 - val_precision: 0.9958 - val_sensitivity: 0.9951 - val_specificity: 0.9986 - val_dice_loss: 0.3732 - val_dice_normal: 0.9991 - val_dice_coef_necrotic: 0.5104 - val_dice_coef_edema: 0.7407 - val_dice_coef_enhancing: 0.6579 - lr: 1.0000e-06
# Epoch 97: early stopping

# %%
model.load_weights('/kaggle/input/model-unet/model.h5')

# %%
model.save('final.h5')

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))
  #  y = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE))
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata() 
    
 #   vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_seg.nii');
 #   seg=nib.load(vol_path).get_fdata()  

    
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
 #       y[j,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        
  #  model.evaluate(x=X,y=y[:,:,:,0], callbacks= callbacks)
    return model.predict(X/np.max(X), verbose=1)


def showPredictsById(case, start_slice = 50):
    path = f"../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50)) 

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')
    
    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image flair')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()
    
    
showPredictsById(case=test_ids[0][-3:])
showPredictsById(case=test_ids[1][-3:])
showPredictsById(case=test_ids[2][-3:])
showPredictsById(case=test_ids[3][-3:])
showPredictsById(case=test_ids[4][-3:])
showPredictsById(case=test_ids[5][-3:])
showPredictsById(case=test_ids[6][-3:])


# mask = np.zeros((10,10))
# mask[3:-3, 3:-3] = 1 # white square in black background
# im = mask + np.random.randn(10,10) * 0.01 # random image
# masked = np.ma.masked_where(mask == 0, mask)

# plt.figure()
# plt.subplot(1,2,1)
# plt.imshow(im, 'gray', interpolation='none')
# plt.subplot(1,2,2)
# plt.imshow(im, 'gray', interpolation='none')
# plt.imshow(masked, 'jet', interpolation='none', alpha=0.7)
# plt.show()
# Out:
# 5/5 [==============================] - 0s 36ms/step
# 5/5 [==============================] - 0s 34ms/step
# 5/5 [==============================] - 0s 33ms/step
# 5/5 [==============================] - 0s 33ms/step
# 5/5 [==============================] - 0s 34ms/step
# 5/5 [==============================] - 0s 34ms/step
# 5/5 [==============================] - 0s 34ms/step

# %%
case = case=test_ids[3][-3:]
path = f"../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)


core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]


i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'



gt[gt != eval_class] = 1 # use only one class for per class evaluation 

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2) 
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 5/5 [==============================] - 0s 34ms/step

# %%
# model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing] )
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 45/45 [==============================] - 32s 676ms/step - loss: 0.0202 - mean_io_u_1: 0.8987 - dice_coef: 0.6157 - precision: 0.9945 - sensitivity: 0.9937 - specificity: 0.9982 - dice_loss: 0.3843 - dice_normal: 0.9988 - dice_coef_necrotic: 0.5555 - dice_coef_edema: 0.6734 - dice_coef_enhancing: 0.6188
# test loss, test acc: [0.020248297601938248, 0.898675799369812, 0.6156752109527588, 0.9945494532585144, 0.9936503171920776, 0.9981728196144104, 0.3843246400356293, 0.9987708926200867, 0.5555254817008972, 0.6734211444854736, 0.6188262104988098]

# %%
history = pd.read_csv('/kaggle/working/training.log', sep=',', engine='python')

hist=history


# hist=history.history
epoch=range(len(iou))

plt.plot(hist['dice_normal'],label='Training Score')
plt.plot(hist['val_dice_normal'],label='Validation Score')
plt.ylabel("Dice Score for necrotic region")
plt.xlabel("Epoch")
plt.legend()
plt.title("Dice Similarity Coefficient Curve") 
plt.savefig('Dice Normal', bbox_inches='tight')

# %%
model.save('dice_only.h5')
